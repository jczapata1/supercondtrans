# %% [markdown]
# **Checklist**

# %% [markdown]
# **1. `programs/base/`**
#
# `make.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `read_parameters`       | OK | OK | OK | OK |
# | `set_parameters`        | OK | OK | OK | OK |
# | `make_setup`            | OK | OK | OK | OK |
# | `make_device`           | OK | OK | OK | OK |
# | `make_epsilon`          | OK | OK | OK | OK |
# | `make_magnetic_field`   | OK | OK | OK | OK |
# | `make_vector_potential` | OK | OK | OK | OK |
#
# `load.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `load_setup`            | OK | OK | OK | OK |
# | `load_parameters`       | OK | OK | OK | OK |
# | `load_device`           | OK | OK | OK | OK |
# | `load_epsilon`          | OK | OK | OK | OK |
# | `load_magnetic_field`   | OK | OK | OK | OK |
# | `load_vector_potential` | OK | OK | OK | OK |
#
# `magnetic_field.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `uniform` | OK | OK | OK | OK |
# | `domains` | OK | OK | OK | OK |
# | `plateau` | OK | OK | OK | OK |
#
# `transport.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `set_current`    | OK | OK | OK | OK |
# | `get_voltage`    | OK | OK | OK | OK |
# | `save_transport` | OK | OK | OK | OK |
#
# `positions.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `random`    | OK | OK | OK | OK |
# | `square`    | OK | OK | OK | OK |
# | `hexagonal` | OK | OK | OK | OK |
#
# `run.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `point` | OK | OK | OK | OK |
# | `sweep` | OK | OK | OK | OK |
#
# `vector_potential.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `vector_potential` | OK | OK | OK | OK |
#
# ---
#
# **2. `programs/post/`**
#
# `animation.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `snapshots` | OK | OK | OK | OK |
# | `animation` | OK | OK | OK | OK |
#
# `plot.py`
#
# | Function | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `plot_device`           | OK | OK | OK | OK |
# | `plot_epsilon`          | OK | OK | OK | OK |
# | `plot_magnetic_field`   | OK | OK | OK | OK |
# | `plot_vector_potential` | OK | OK | OK | OK |
# | `plot_psi`              | OK | OK | OK | OK |
# | `plot_phase`            | OK | OK | OK | OK |
# | `plot_vorticity`        | OK | OK | OK | OK |
# | `plot_normal_current`   | OK | OK | OK | OK |
# | `plot_super_current`    | OK | OK | OK | OK |
# | `plot_scalar_potential` | OK | OK | OK | OK |
# | `plot_current_voltage`  | OK | OK | OK | OK |
#
# ---
#
# **3. `programs/`**
#
# `tdgl_animation.py` — `TDGLAnimation`
#
# | Method | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `snapshots`     | OK | OK | --- | OK |
# | `animation`     | OK | OK | --- | OK |
# | `clean`         | OK | OK | --- | OK |
#
# `tdgl_setup.py` — `TDGLSetup`
#
# | Method | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `set_parameters`        | OK | OK | --- | OK |
# | `make_setup`            | OK | OK | --- | OK |
# | `plot_device`           | OK | OK | --- | OK |
# | `plot_epsilon`          | OK | OK | --- | OK |
# | `plot_magnetic_field`   | OK | OK | --- | OK |
# | `plot_vector_potential` | OK | OK | --- | OK |
# | `clean`                 | OK | OK | --- | OK |
#
# `tdgl_simulation.py` — `TDGLSimulation`
#
# | Method | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `load_setup`            | OK | OK | --- | OK |
# | `set_current`           | OK | OK | --- | OK |
# | `point`                 | OK | OK | --- | OK |
# | `sweep`                 | OK | OK | --- | OK |
# | `plot_psi`              | OK | OK | --- | OK |
# | `plot_phase`            | OK | OK | --- | OK |
# | `plot_vorticity`        | OK | OK | --- | OK |
# | `plot_normal_current`   | OK | OK | --- | OK |
# | `plot_super_current`    | OK | OK | --- | OK |
# | `plot_scalar_potential` | OK | OK | --- | OK |
# | `plot_current_voltage`  | OK | OK | --- | OK |
# | `compress`              | OK | OK | --- | OK |
# | `clean`                 | OK | OK | --- | OK |
#
# ---
#
# **4. `input/`**
#
# | File/Folder | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `README.md` | OK  | --- | --- | OK  |
# | `Input.in`  | --- | OK  | --- | OK  |
# | `Default/`  | --- | --- | OK  | OK  |
# | `Setup/`    | --- | --- | OK  | OK  |
# | `Epsilon/`  | --- | OK  | --- | OK  |
# | `Fields/`   | --- | OK  | --- | OK  |
# | `Current/`  | --- | OK  | --- | OK  |
#
# ---
#
# **5. `output/`**
#
# | Folder | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `Default/` | --- | --- | OK  | OK  |
# | `Static/`  | --- | --- | OK  | OK  |
# | `Dynamic/` | --- | --- | OK  | OK  |
# | `Sweep/`   | --- | --- | OK  | OK  |
#
# ---
#
# **6. Notebooks**
#
# | Notebook | Documentation | Code | Data | Complete |
# |:---:|:---:|:---:|:---:|:---:|
# | `README.md`        | OK  | --- | --- | OK |
# | `Setup.ipynb`      | OK  | OK  | --- | OK |
# | `Simulation.ipynb` | OK  | OK  | --- | OK |
