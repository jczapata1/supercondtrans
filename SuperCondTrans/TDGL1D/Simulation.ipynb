# %% [markdown]
# **Simulation**

# %%
from programs.tdgl1d_simulation import TDGL1DSimulation
from programs.tdgl1d_animation import TDGL1DAnimation

# %%
# Parameters
folder = './output'
sim    = TDGL1DSimulation(folder=folder)

# %%
# Load
sim.read_parameters(file='./input/Input.in')

# %%
# Simulation
sim.run()
sim.plot()

# Animation
anim = TDGL1DAnimation(folder=folder)
anim.solution = sim.solution
anim.snapshots(n=50)
anim.animation()

# %% [markdown]
# **Quick Guide**
#
# `mode:`
#
# * Single: single vortex-like potential profile.
# * Train: periodic train of vortex-like potential profiles.
