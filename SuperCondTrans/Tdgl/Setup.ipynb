# %% [markdown]
# **Setup**

# %%
from programs.tdgl_setup import TDGLSetup

# %%
setup = TDGLSetup(folder='./input/Setup')

# %%
# Load
setup.set_parameters(file='./input/Input.in')

# Make
setup.make_setup()

# Plot
setup.plot_device()
setup.plot_epsilon()
setup.plot_magnetic_field()
setup.plot_vector_potential()

# %% [markdown]
# **Quick Guide**
#
# `disorder:`
#
# * NoPinning: no antidot pinning.
# * Pinning: antidot pinning configuration.
# * Antipinning: antidot antipinning configuration.
#
# `profile:`
#
# * Uniform: uniform magnetic field profile.
# * Plateau: plateau magnetic field profile.
# * Domains: periodic stripe domain magnetic field profile.
