# %% [markdown]
# **Device**

# %%
from programs.tdgl_device import TDGLDevice

# %%
dev = TDGLDevice(folder='./input/Device')

# %%
# Load
dev.read_parameters(file='./input/Input.in')

# Make
dev.make_device()                           

# Plot
dev.plot_device()
